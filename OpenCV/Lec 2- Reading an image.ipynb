# %%
import numpy as np
import cv2

# %%
## Read an Image syantx: cv2.imread(filepath)

img=cv2.imread('/Users/priyanshugupta/Desktop/OpenCV/airplane.png')
print(type(img)) ## this is a numpy array
# Out:
# <class 'numpy.ndarray'>

# %%
img.shape ## RGB image
# Out:
# (3072, 3072, 3)

# %%
## To display an Image
cv2.imshow("window",img)

## to keep the image on window 
cv2.waitKey(0) ## 0 will keep the image forever on board
