# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
df=pd.read_csv('/Users/priyanshugupta/Desktop/scikit learn/CAR DETAILS FROM CAR DEKHO.csv')
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df=df[['selling_price','km_driven','year']]
df
# Out:
#       selling_price  km_driven  year
# 0             60000      70000  2007
# 1            135000      50000  2007
# 2            600000     100000  2012
# 3            250000      46000  2017
# 4            450000     141000  2014
# ...             ...        ...   ...
# 4335         409999      80000  2014
# 4336         409999      80000  2014
# 4337         110000      83000  2009
# 4338         865000      90000  2016
# 4339         225000      40000  2016
#
# [4340 rows x 3 columns]

# %% [markdown]
# ## Applying normalization (min-max scaling)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## use preprocessing library of sklearn and then import MinMaxScaler


from sklearn.preprocessing import MinMaxScaler

# %%
## create object of MinMaxScaler

scaler=MinMaxScaler()

# %%
## fit_transform(dataframe_name)
new_df=scaler.fit_transform(df) ## transforms the value of data column wise
new_df
# Out:
# array([[0.0045045 , 0.08678301, 0.53571429],
#        [0.01295045, 0.06198751, 0.53571429],
#        [0.06531532, 0.12397626, 0.71428571],
#        ...,
#        [0.01013514, 0.10290008, 0.60714286],
#        [0.09515766, 0.11157851, 0.85714286],
#        [0.02308559, 0.04958976, 0.85714286]], shape=(4340, 3))

# %%
new_df=pd.DataFrame(data=new_df,columns=df.columns)
new_df
# Out:
#       selling_price  km_driven      year
# 0          0.004505   0.086783  0.535714
# 1          0.012950   0.061988  0.535714
# 2          0.065315   0.123976  0.714286
# 3          0.025901   0.057028  0.892857
# 4          0.048423   0.174807  0.785714
# ...             ...        ...       ...
# 4335       0.043919   0.099181  0.785714
# 4336       0.043919   0.099181  0.785714
# 4337       0.010135   0.102900  0.607143
# 4338       0.095158   0.111579  0.857143
# 4339       0.023086   0.049590  0.857143
#
# [4340 rows x 3 columns]

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split
X=df.drop('selling_price',axis=1)
y=df['selling_price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=43)

# %%
X_train
# Out:
#       km_driven  year
# 788       90000  2014
# 1654      50000  2012
# 4144      56000  2013
# 1013      22155  2018
# 3483      55000  2013
# ...         ...   ...
# 307       44000  2013
# 2064      60000  2015
# 2325      80000  2010
# 2303      99117  2014
# 3392      15000  2018
#
# [3472 rows x 2 columns]

# %%
X_test
# Out:
#       km_driven  year
# 3455      20000  2019
# 1187      70950  2008
# 21        25000  2015
# 4211      40000  2019
# 3530      98000  2013
# ...         ...   ...
# 2167     186000  2010
# 1898      60000  2013
# 710       32670  2017
# 651       50000  2017
# 1758      12000  2014
#
# [868 rows x 2 columns]

# %%
## we do scaling after train-test split always

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.fit_transform(X_test)

# %%
X_train_scaled=pd.DataFrame(data=X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(data=X_test_scaled,columns=X_test.columns)

# %%
X_train_scaled
# Out:
#       km_driven      year
# 0      0.160713  0.750000
# 1      0.089284  0.666667
# 2      0.099998  0.708333
# 3      0.039561  0.916667
# 4      0.098213  0.708333
# ...         ...       ...
# 3467   0.078570  0.708333
# 3468   0.107141  0.791667
# 3469   0.142856  0.583333
# 3470   0.176993  0.750000
# 3471   0.026784  0.916667
#
# [3472 rows x 2 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df=pd.read_csv('/Users/priyanshugupta/Desktop/scikit learn/Social_Network_Ads.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.drop('User ID',axis=1,inplace=True)

# %%
df['Gender']=df['Gender'].map({'Male':0,'Female':1})
df
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         0   19            19000          0
# 1         0   35            20000          0
# 2         1   26            43000          0
# 3         1   27            57000          0
# 4         0   19            76000          0
# ..      ...  ...              ...        ...
# 395       1   46            41000          1
# 396       0   51            23000          1
# 397       1   50            20000          1
# 398       0   36            33000          0
# 399       1   49            36000          1
#
# [400 rows x 4 columns]

# %% [markdown]
# ## Applying StandardScaler

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
scaler=StandardScaler()
X=df.drop('Purchased',axis=1)
y=df['Purchased']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=34)

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.fit_transform(X_test)

# %%
X_train_scaled=pd.DataFrame(data=X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(data=X_test_scaled,columns=X_test.columns)

# %%
X_train_scaled
# Out:
#        Gender       Age  EstimatedSalary
# 0    0.981423  0.135662         0.251190
# 1    0.981423 -0.909260        -0.348219
# 2    0.981423  0.420641         0.281160
# 3    0.981423  0.325648         0.041397
# 4    0.981423 -0.814267        -0.707864
# ..        ...       ...              ...
# 315  0.981423  0.990598         1.809652
# 316  0.981423 -0.624282         1.420036
# 317  0.981423 -0.244310        -0.617953
# 318  0.981423  1.465563        -1.097480
# 319  0.981423  0.230655         0.131308
#
# [320 rows x 3 columns]

# %%
np.round(X_train.describe(),2)
# Out:
#        Gender     Age  EstimatedSalary
# count  320.00  320.00           320.00
# mean     0.51   37.57         70618.75
# std      0.50   10.54         33418.48
# min      0.00   18.00         15000.00
# 25%      0.00   29.00         47000.00
# 50%      1.00   37.00         70000.00
# 75%      1.00   45.00         87250.00
# max      1.00   60.00        150000.00

# %%
import numpy as np
np.round(X_train_scaled.describe(),2)
# Out:
#        Gender     Age  EstimatedSalary
# count  320.00  320.00           320.00
# mean    -0.00    0.00            -0.00
# std      1.00    1.00             1.00
# min     -1.02   -1.86            -1.67
# 25%     -1.02   -0.81            -0.71
# 50%      0.98   -0.05            -0.02
# 75%      0.98    0.71             0.50
# max      0.98    2.13             2.38

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
