# %% [markdown]
# ## Virtual Environment
#
# its like it gives you a new computer with basic python installed . when you open terminal and activate the virtual environment, then you feel like i am in a freshly new machine where python is installed.You can install whatever you want and it won't affect and go into the python of your main system.
#
# to open -> click on file ->open in integrated terminal
#
#
# By installing virtualenv,I can create virtual environment.
#
# pip install virtualenv (in terminal)

# %%
## to create virtual environment

## synatx: virtualenv -p python3 env_name
#  ex: virtualenv venv

## alternate : python -m venv env_name/path_to_new_env
## ex: python -m .venv

# %%
## to activate env

## mac:  soure env_name/bin/activate 

## windows: .\env_name\Scripts\activate

## you will enter the virtual env by this

# %%
## confirm env is successfully selected
## python --version

# %%
## to see all the packages installed : pip list

# %%
## to install packages: pip install package_name 
##it is installed in virtual env

# %%
## we can store all these modules in a text file:

## pip list > requirement.txt (I redirect into this text file)

# %%
## to install the packages from requirement.txt:


## pip install -r requirement.txt

# %%
## to deactivate the env ( env se bahar kaise jaye):

## syntax: deactivate

# %% [markdown]
# ## Using conda

# %%
## to create env :   conda create -p env_name python==3.10 -y
