# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# there are 7 divs in 1st image and 2 divs in second image
#
# inside each div we implement their specific function

# %% [markdown]
# Bootstrap sees the webpage in 12 equal parts
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## steps:
#
# 1- we create outerdiv and we will name it container and inside outerdiv all the divs will be there
#
# ![image.png](attachment:image.png)
#
# 2- first 4 divs become 1st row, second 2 divs become 2nd row and last div becomes 3rd row
#
# Note: every row has 12 columns bcz bootstrap divides webpage into 12 parts

# %% [markdown]
# ## Architecture
#
# ![image-2.png](attachment:image-2.png)
#
#
# these all add up to 12 (3+3+3+3 or 6+6 or 12)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# Hierarchy: container -> row -> card -> card-body (we write text in card-body with limit 634 characters)
